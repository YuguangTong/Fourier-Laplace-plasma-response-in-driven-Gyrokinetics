# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline
import matplotlib as mpl
fs = 16
mpl.rcParams['font.size'] = fs-2
mpl.rcParams['axes.labelsize'] = fs
mpl.rcParams['axes.titlesize'] = fs
mpl.rcParams['xtick.labelsize'] = fs
mpl.rcParams['ytick.labelsize'] = fs
mpl.rcParams['legend.fontsize'] = fs-2

# %% [markdown]
# ## slow mode with decorrelation rate = -0.8

# %%
file_dir = '/Volumes/yuguang_sd/data/agk/lin_response/upar_160929_slow_decay/'
file, heat, t, Ebperp, Ebpar = {},  {}, {}, {}, {}
file_ind = [1, 2, 7, 8]
for i in file_ind:
    file[i] = file_dir + 'lin_upar_{}'.format(str(i)) + '.heat'
    heat[i] = np.loadtxt(file[i])
    t[i], Ebperp[i], Ebpar[i] =heat[i][:, 0], heat[i][:, 2], heat[i][:, 3]
labels = {1:'drive (decorr=0)', 2:'decay (decorr=0)', 
          3:'drive (decorr=0.1)', 4:'decay (decorr=0.1)',
          7:'drive (decorr=0.8)', 8:'decay (decorr=0.8)'}

# %%
fig_ebpar, ax = plt.subplots(figsize=(8, 8*0.618))

for i in file_ind:
    ax.plot(t[i], Ebpar[i], label = labels[i])
ax.set_yscale('log')
# ax.set_ylim(1e-3, 1e-1)
ax.legend(loc='best')
ax.set_ylabel('$E_{B_\parallel}$')
ax.set_xlabel('$tk_\parallel v_{ti}$')
# fig_ebpar.savefig('lin_slow_decay_3.png', dpi=200)
plt.show()

# %%
fig_mva, ax = plt.subplots(figsize=(8, 8*0.618))
for i in file_ind:
    if i % 2 == 1:
        ax.plot(t[i][1:], Ebperp[i][1:]/Ebpar[i][1:], label = labels[i])
    else:
        ax.plot(t[i], Ebperp[i]/Ebpar[i], label = labels[i])
ax.set_yscale('log')
ax.legend(loc='best')
ax.set_ylabel('MVA')
ax.set_xlabel('$tk_\parallel v_{ti}$')
# fig_mva.savefig('lin_slow_decay_mva_3.png', dpi=200)
plt.show()

# %%
i, k = 7, 200
print(np.mean(Ebperp[i][-k:]/Ebpar[i][-k:]))
np.exp(np.mean(np.log(Ebperp[i][-k:]/Ebpar[i][-k:])))
# Out:
# 3.04531672313
# 0.22968179049184417

# %%
# mv *png figures/

# %%
## Alfven mode with decorrelation rate = 0.8

# %%
file_dir = '/Volumes/yuguang_sd/data/agk/lin_response/upar_160929_alfven_decay/'
file, heat, t, Ebperp, Ebpar = {},  {}, {}, {}, {}
file_ind = [1, 2]
for i in file_ind:
    file[i] = file_dir + 'lin_upar_{}'.format(str(i)) + '.heat'
    heat[i] = np.loadtxt(file[i])
    t[i], Ebperp[i], Ebpar[i] =heat[i][:, 0], heat[i][:, 2], heat[i][:, 3]
labels = {1:'drive (decorr=0.8)', 2:'decay'}

# %%
fig_ebperp, ax = plt.subplots(figsize=(8, 8*0.618))

for i in file_ind:
    ax.plot(t[i], Ebperp[i], label = labels[i])
ax.set_yscale('log')
# ax.set_ylim(1e-3, 1e-1)
ax.legend(loc='best')
ax.set_ylabel('$E_{B_\perp}$')
ax.set_xlabel('$tk_\parallel v_{ti}$')
# fig_ebperp.savefig('lin_alfven_decay_Ebperp_1.png', dpi=200)
plt.show()

# %%
fig_mva, ax = plt.subplots(figsize=(8, 8*0.618))
for i in file_ind:
    if i % 2 == 1:
        ax.plot(t[i][1:], Ebperp[i][1:]/Ebpar[i][1:], label = labels[i])
    else:
        ax.plot(t[i], Ebperp[i]/Ebpar[i], label = labels[i])
ax.set_yscale('log')
ax.set_ylim(0, 2e4)
ax.set_xlim(60, 70)
ax.legend(loc='best')
ax.set_ylabel('MVA')
ax.set_xlabel('$tk_\parallel v_{ti}$')
# fig_mva.savefig('lin_alfven_decay_mva_1.png', dpi=200)
plt.show()

# %%
ls figures/
# Out:
# AGK_mva_w0_1.png          fig_bpar_tf.eps           lin_slow_decay_mva_2.png
# AGK_mva_w0_2.png          fig_bpar_w0.eps           lin_slow_decay_mva_3.png
# Ebpar_t_w0_1.png          fig_bpar_w0_2.eps         lin_slow_nz_1.eps
# Ephi_t_w0_1.png           fig_phi_temp_1.eps        lin_slow_phi_z_1.eps
# FL_bpar_t_w0_1.png        fig_phi_tf.eps            mix_Ebpar_1.png
# FL_bphi_t_w0_1.png        fig_phi_w0.eps            mix_Ebpar_decay_1.png
# agk_apar_cadence.eps      fig_phi_w0_2.eps          mix_Ebperp_1.png
# agk_bpar_cadence.eps      lin_slow_bparz_1.eps      mix_Ebperp_decay_1.png
# agk_phi_cadence.eps       lin_slow_decay_1.png      mix_mva_1.png
# bromwich_vs_agk.eps       lin_slow_decay_2.png      mix_mva_decay_1.png
# bromwich_vs_approx.eps    lin_slow_decay_3.png
# fig_bpar_temp_1.eps       lin_slow_decay_mva_1.png

# %%
# mv *png figures/
