# %% [markdown]
# To do this week
# ===============
# - drive linear modes in unity beta plasma
# - drive slow mode with $u_0=475$ and Alfven mode with $A_0=30$ to make sure that energy is equally partitioned when the decorrelation rate is zero.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline
import matplotlib as mpl
fs = 16
mpl.rcParams['font.size'] = fs-2
mpl.rcParams['axes.labelsize'] = fs
mpl.rcParams['axes.titlesize'] = fs
mpl.rcParams['xtick.labelsize'] = fs
mpl.rcParams['ytick.labelsize'] = fs
mpl.rcParams['legend.fontsize'] = fs-4

# %%
file_dir = '/Volumes/yuguang_sd/data/agk/lin_response/upar_160929_equal_erg/'
# file_dir = '/Volumes/yuguang_sd/data/agk/lin_response/stampede_equal_erg/'
file, heat, t, Ebperp, Ebpar = {},  {}, {}, {}, {}
file_ind = [3, 4, 5]
for i in file_ind:
    file[i] = file_dir + 'lin_upar_{}'.format(str(i)) + '.heat'
    heat[i] = np.loadtxt(file[i])
    t[i], Ebperp[i], Ebpar[i] =heat[i][:, 0], heat[i][:, 2], heat[i][:, 3]
labels = {3:'Alfven {}, slow {}'.format(r'$\overline{\omega}_0=0.9, DR=0$', r'$\overline{\omega}_0=0.13, DR=0$'),
          4:'Alfven {}, slow {}'.format(r'$\overline{\omega}_0=0.9, DR=0.8$', r'$\overline{\omega}_0=0.13, DR=0$'),
          5:'Alfven {}, slow {}'.format(r'$\overline{\omega}_0=0.9, DR=0.8$', r'$\overline{\omega}_0=0.13, DR=0.8$')}

# %%
fig_mva, ax = plt.subplots(figsize=(8, 8*0.618))
for i in file_ind:
        ax.plot(t[i][1:], Ebperp[i][1:]/Ebpar[i][1:], label = labels[i])
ax.set_yscale('log')
ax.legend(loc='best', frameon=False)
ax.set_ylabel('MVA')
ax.set_xlabel('$tk_\parallel v_{ti}$')
# fig_mva.savefig('lin_mix_mva_1.png', dpi=200)
plt.show()

# %%
# !ls figures/
# !mv *png figures

# %%
fig_bpar, ax = plt.subplots(figsize=(8, 8*0.618))
for i in file_ind:
        ax.plot(t[i], Ebpar[i], label = labels[i])
ax.set_yscale('log')
ax.legend(loc='best', frameon=False)
ax.set_ylabel('$E_{B_\parallel}$')
ax.set_xlabel('$tk_\parallel v_{ti}$')
# fig_bpar.savefig('lin_mix_Ebpar_1.png', dpi=200)
plt.show()

# %%
fig_bperp, ax = plt.subplots(figsize=(8, 8*0.618))
for i in file_ind:
        ax.plot(t[i], Ebperp[i], label = labels[i])
ax.set_yscale('log')
ax.legend(loc='best', frameon=False)
ax.set_ylabel('$E_{B_\perp}$')
ax.set_xlabel('$tk_\parallel v_{ti}$')
# fig_bperp.savefig('lin_mix_Ebperp_1.png', dpi=200)
plt.show()

# %%
# mv *png figures

# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline
import matplotlib as mpl
fs = 16
mpl.rcParams['font.size'] = fs-2
mpl.rcParams['axes.labelsize'] = fs
mpl.rcParams['axes.titlesize'] = fs
mpl.rcParams['xtick.labelsize'] = fs
mpl.rcParams['ytick.labelsize'] = fs
mpl.rcParams['legend.fontsize'] = fs-4

# %% [markdown]
# ## alfven mode decay

# %%
file_dir = '/Volumes/yuguang_sd/data/agk/lin_response/bi_unity_alfven/'
file, heat, t, Ebperp, Ebpar = {},  {}, {}, {}, {}
file_ind = [3, 4]
for i in file_ind:
    file[i] = file_dir + 'lin_upar_{}'.format(str(i)) + '.heat'
    heat[i] = np.loadtxt(file[i])
    t[i], Ebperp[i], Ebpar[i] =heat[i][:, 0], heat[i][:, 2], heat[i][:, 3]
labels = {3:'Alfven {}'.format(r'$\overline{\omega}_0=0.9, DR=0$'), 
         4: 'decay'}

# %%
fig_Ebperp, ax = plt.subplots(figsize=(8, 8*0.618))
for i in file_ind:
        ax.plot(t[i], Ebperp[i], label = labels[i])
#         ax.plot(t[i], Ebperp[i], label = labels[i])

ax.set_yscale('log')
ax.legend(loc='best', frameon=False)
ax.set_ylabel('$E_{B_\perp}$')
ax.set_xlabel('$tk_\parallel v_{ti}$')
# fig_Ebperp.savefig('lin_bi_1_alfven_Ebperp_1.png', dpi=200)
plt.show()

# %%
fig_mva, ax = plt.subplots(figsize=(8, 8*0.618))
for i in file_ind:
        ax.plot(t[i][1:], Ebperp[i][1:]/Ebpar[i][1:], label = labels[i])
#         ax.plot(t[i], Ebperp[i], label = labels[i])

ax.set_yscale('log')
ax.legend(loc='best', frameon=False)
ax.set_ylabel('MVA')
ax.set_xlabel('$tk_\parallel v_{ti}$')
# fig_mva.savefig('lin_bi_1_alfven_mva_1.png', dpi=200)
plt.show()

# %% [markdown]
# ## slow mode decay

# %%
file_dir = '/Volumes/yuguang_sd/data/agk/lin_response/bi_unity_slow/'
file, heat, t, Ebperp, Ebpar = {},  {}, {}, {}, {}
file_ind = [3, 4]
for i in file_ind:
    file[i] = file_dir + 'lin_upar_{}'.format(str(i)) + '.heat'
    heat[i] = np.loadtxt(file[i])
    t[i], Ebperp[i], Ebpar[i] =heat[i][:, 0], heat[i][:, 2], heat[i][:, 3]
labels = {3:'slow {}'.format(r'$\overline{\omega}_0=1.1, DR=0$'), 4:'decay'}

# %%
Ebperp[3][-1]
# Out:
# 3.6332

# %%
fig_Ebpar, ax = plt.subplots(figsize=(8, 8*0.618))
for i in file_ind:
    ax.plot(t[i], Ebpar[i], label = labels[i])

ax.set_yscale('log')
ax.legend(loc='best', frameon=False)
ax.set_ylabel('$E_{B_\parallel}$')
ax.set_xlabel('$tk_\parallel v_{ti}$')
# fig_Ebpar.savefig('lin_bi_1_slow_Ebpar_1.png', dpi=200)
plt.show()

# %%
fig_mva, ax = plt.subplots(figsize=(8, 8*0.618))
for i in file_ind:
    ax.plot(t[i][1:], Ebperp[i][1:]/Ebpar[i][1:], label = labels[i])

ax.set_yscale('log')
ax.legend(loc='best', frameon=False)
ax.set_ylabel('MVA')
ax.set_xlabel('$tk_\parallel v_{ti}$')
# fig_mva.savefig('lin_bi_1_slow_mva_1.png', dpi=200)
plt.show()

# %%
ls *png
# Out:
# lin_bi_1_alfven_Ebperp_1.png  lin_bi_1_alfven_mva_1.png

# %%
# !mv *png figures/

# %%
! open figures/lin_bi_1_slow_Ebpar_1.png

# %%
# rm figures/lin_bi_1_*png
